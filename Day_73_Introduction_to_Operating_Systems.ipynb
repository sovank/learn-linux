# %% [markdown]
# <a href="https://colab.research.google.com/github/sovank/learn-linux/blob/main/Day_73_Introduction_to_Operating_Systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 11

# %% [markdown]
# TASK - 1:
#
# Let us start with a simple command to know the user's current location. Run the command in the terminal and store the output returned on the terminal in the answer.txt file using the below command:
#
# echo output >> /home/user/answer.txt
#
# Replace output with the value to be stored in answer.txt. For example, if the value to be stored is sudo, then the above command will look like this:
#
# echo sudo >> /home/user/answer.txt
#
# NOTE: Storing only the command name will pass all the test cases, make sure nothing else is stored in the answer.txt file.

# %%
# Answer
# pwd -> /home/user
# echo /home/user >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# TASK - 2:
#
# A directory named task_1 has been created in your current location. Use a Linux command to change directory to the task_1 directory.
#
# Store the command used to move to the task_1 directory in answer.txt using the below code:
#
# echo command_name >> /home/user/answer.txt

# %%
# Answer
# cd task_1
# echo cd >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# TASK - 3:
#
# We have created some directories in the task_1 directory. Use a Linux command to list all the directories present in it.
#
# Store the command used to list files and directories in the task_1 directory in answer.txt using the below code:
#
# echo command_name >> /home/user/answer.txt

# %%
# Answer
# ls
# echo ls >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# TASK - 4:
#
# We have stored a hidden file in the task_1 directory. Use a Linux command to list all the files in a directory and hidden files using arguments or flags with the ls command.
#
# Store the name of the hidden file in the task_1 directory in answer.txt using the below code:
#
# echo file_name >> /home/user/answer.txt

# %%
# Answer
# ls -a
# echo .hidden_file >> /home/user/answer.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Question 12

# %% [markdown]
# TASK - 1:
#
# Move to the task_1 directory and copy the cp.txt file. Then, paste the copied file into the task_2 directory.
#
# Store the command used to copy the file in the answer.txt file using the below command:
#
# echo command_name >> /home/user/answer.txt

# %%
# Answer
# cd task_1
# cp cp.txt /home/user/task_2
# echo cp >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# TASK - 2:
#
# Nice work copying the file. Now, let's take a step ahead, and instead of copying the file, try to move the mv.txt file into the task_3 directory.
#
# Store the command used to move the file in the answer.txt file using the below command:
#
# echo command_name >> /home/user/answer.txt

# %%
# Answer
# cd task_1
# mv mv.txt /home/user/task_3
# echo mv >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# TASK - 3:
#
# To conclude the basic Linux command list, let's try to use a command to get a complete manual of a certain command. Using this command, one can easily read about each and every detail of a command.
#
# Store the command in the answer.txt file using the below command:
#
# echo command_name >> /home/user/answer.txt

# %%
# Answer
# man command to get the details of any command
# echo man >> /home/user/answer.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Question 13

# %% [markdown]
# Mission 1: The Quest Begins - Unveil Your Origin
#
# Greetings, brave explorer! Your first challenge on this grand Linux Toolkit Adventure beckons. A wise adventurer knows where their journey begins, for it is from the starting point that all great quests are embarked upon. Your mission, should you embrace it, is to unveil the very ground on which you stand within the vast expanse of the digital cosmos.
#
# In the terminal's silent echoes, craft a secret chamber named starting_point. Know your surroundings, for knowledge is power, and power is what you'll need to overcome the challenges ahead.
#
# Answer wisely, and you shall unlock the door to your next adventure.
#
# Task - 1:
#
# Check if the secret chamber named starting_point exists. If it does not, go ahead and create one.

# %%
# Answer
# mkdir starting_point

# %% [markdown]
# ---

# %% [markdown]
# Task - 2:
#
# Move to starting_point and create a file named secret_lair.txt.

# %%
# Answer
# cd starting_point
# touch secret_lair.txt

# %% [markdown]
# ---

# %% [markdown]
# Task - 3:
#
# Move back to /home/user. You will find a directory named delete_directory, which you must delete.

# %%
# Answer
# cd ..
# rmdir delete_directory

# %% [markdown]
# ---

# %% [markdown]
# Task - 4:
#
# You will also find a file named delete.txt in the current path. Your task is to delete this file.

# %%
# Answer
# rm delete.txt
# remove write-protected regular empty file 'delete.txt'?
# type --> yes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Question 14

# %% [markdown]
# **NOTE**:
#
# In the assignment you might use **sudo command** to execute few tasks. The sudo command allows a permitted user to execute a command as the superuser or another user, as specified by the security policy. It is commonly used to perform administrative tasks that require elevated privileges.
#
# Running the sudo command in the terminal requires a password. Use user@123! when asked for a password while running sudo.

# %% [markdown]
# ---

# %% [markdown]
# Task - 1:
#
# You have created your secret chamber named starting_point, now it's time to check if secret_lair is present in starting_point. If yes, then check how many rooms are present in the secret_lair.
#
# Store the answer in the answer.txt file using the below code:
#
# echo no_of_room >> /home/user/answer.txt

# %%
# Answer
# cd starting_point/secret_lair
# ls
# There will be 3 rooms
# echo 3 >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# Task - 2:
#
# Which room has been magically sealed and is inaccessible without special permission?
#
# Store the answer in the answer.txt file using the below code:
#
# echo name_of_room >> /home/user/answer.txt

# %%
# cd room2 (will give bash: cd: room2: Permission denied)
# echo room2 >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# Task -3 :
#
# What command was used to change the ownership of the room to root?
#
# Store the answer in the answer.txt file using the below code:
#
# echo command-name >> /home/user/answer.txt
#
# The command should be stored in this format: sudo command-name root:root ~/starting_point/secret_lair/room2

# %%
# Answer
# sudo chown root:root /home/user/starting_point/secret_lair/room2 will change the ownership of the room to root
# But the answer is echo sudo chown user:user /home/user/starting_point/secret_lair/room2 >> /home/user/answer.txt
# I am trying to find the answer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Question 15

# %% [markdown]
# **NOTE:**
#
# Running the sudo command in the terminal requires a password. Use user@123! when asked for a password while running sudo.

# %% [markdown]
# ---

# %% [markdown]
# TASK - 1:
#
# Move to starting_point/secret_lair and try to access room1 and read the file present in it. We see that the file is under root but still inaccessible. Use a command to change the permissions of the file.
#
# Store the command in the answer.txt file using the below command:
#
# echo sudo command-name permission-number >> /home/user/answer.txt

# %%
# Answer
# cd starting_point/secret_lair
# sudo chmod 777 /home/user/starting_point/secret_lair/room1
# echo sudo chmod 777 >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# TASK - 2:
#
# What is the name of the file present in room1?
#
# Store the file name in the answer.txt file using the below command:
#
# echo name_of_file >> /home/user/answer.txt

# %%
# Answer
# ls /home/user/starting_point/secret_lair/room1
# echo super_secret_clue.txt >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# TASK - 3:
#
# Move to room2 and read the file present in it. What command would reveal the number of lines and words in treasure_story.txt?
#
# Store the command in the answer.txt file using the below code:
#
# echo command-name >> /home/user/answer.txt

# %%
# Answer
# cd /home/user/starting_point/secret_lair
# sudo chmod 777 room2
# ls
# wc treasure_story.txt
# echo wc >> /home/user/answer.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
