# %% [markdown]
# <a href="https://colab.research.google.com/github/sovank/learn-linux/blob/main/Day_79_Memory_%26_Storage_Management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q11. DevOps Class - 5 Assignment - 1

# %% [markdown]
# Objective:
#
# In this class, we have learned the concepts of memory management in Linux. Let's start with a basic question and try to find the below details using a single command:
#
# NOTE: Only store the integer(**ignore**) value of the memory to pass all the test cases and in order as per tasks listed.

# %% [markdown]
# TASK - 1: Store the value of total memory in the answer.txt file.

# %%
# Answer
# free -h
# echo 3.7 >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# TASK - 2: Store the value of available memory in the answer.txt file.
#
# Tip: Make proper use of flags to convert the value to readable human form.

# %%
# Answer
# free -h
# echo 3.1 >> /home/user/answer.txt

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Q12. DevOps Class - 5 Assignment - 2

# %% [markdown]
# Objective:
# This assignment will teach us how to use tmux to run multiple terminals for different use cases. We will require usage of tmux in next assignments.

# %% [markdown]
# ---

# %% [markdown]
# Step - 1:
# Run tmux in the terminal. If the output throws error of command not found, you can install tmux using the below command:
#
# sudo apt-get update
# sudo apt-get install tmux
#
# NOTE: Password for sudo is user@123!
#
# You will see a terminal-type window that showcases a single tmux terminal.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# Step - 2:
#
# To split the terminal vertically,
#
#  - Press Ctrl + B, then release both keys.
#  - Press % (shift + 5).
#
# This will split the terminal vertically, creating two panes side by side.press control + B followed by % on your keyboard. You will see the split in the terminal, and by default, you will land in the second terminal.
#
# You can make use of both terminals parallely and execute multiple processes at the same time. By repeating the same step you can split the terminal in more sections.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# Step - 3:
# To split the terminal horizontally, press control + B followed by " on your keyboard.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# Step - 4:
# To switch between terminals, press control + B and use the arrow keys to change the terminal.

# %% [markdown]
# NOTE: Click on submit button after playing around with tmux.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
