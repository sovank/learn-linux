# %% [markdown]
# <a href="https://colab.research.google.com/github/sovank/learn-linux/blob/main/Day_80_Introduction_to_Shell_Scripting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q9. DevOps Class - 6-Assignment - 1

# %% [markdown]
# In the script file greet_user.sh already present on path /home/user write a script that interacts with the user to gather their name, then displays a personalized greeting along with the current date and time. This assignment reinforces the understanding of the echo, read, and command substitution using $(command) to create a dynamic and interactive script experience.

# %% [markdown]
# ---

# %% [markdown]
# TASK 1:
#
# Create a shell script to gather user input. Develop the initial part of the shell script to interact with the user and gather their name.The script must prompt the user to input their name.
#
#
#
# Steps:
#
# Use the echo command to display a prompt asking the user to enter their name. The prompt should be exactly the same given in the output example.
#
# Use the read command to capture the user's input.
#
#
#
# After completing the task-1, run the following command in the terminal ./greet_user.sh
#
#
#
# Output Example:
#
# Please enter your name:

# %%
# vi greet_user.sh

# code in file
  # !/bin/bash

  # echo "Please enter your name:"
  # read name

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# TASK 2:
#
# Enhance the script to display a personalized greeting using the user's name. After receiving the input, display a greeting message that includes the user's name.
#
#
#
# Steps:
#
#
#
# Continue editing the greet_user.sh script.
#
# Use the echo command to display a greeting message that incorporates the user's name.
#
#
#
# After completing the task-2, run the following command in the terminal ./greet_user.sh
#
#
#
# Input Example: User types their name, e.g., "Alex". You can type any name according to your choice.
#
# Output Example:
#
# Hello, $user_name! Welcome to Shell Scripting Class!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# TASK 3:
#
# Show the current date and time as part of the greeting.
#
#
#
# Steps:
#
#
#
# Continue editing the greet_user.sh script.
#
# Use command substitution $(command) in variable currentdatetime to get the current date and time.
#
# Display the current date and time along with the greeting.
#
#
#
# After completing the task-3, run the following command in the terminal ./greet_user.sh
#
#
#
# Output Example:
#
# Current date and time: $[current-date-time]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # Q10. DevOps Class - 6-Assignment - 2

# %% [markdown]
# In the script file file_info.sh already present on path /home/user write a script that performs checks on a file check.txt to verify its existence, type, and readability, and outputs appropriate messages for each of these checks.

# %% [markdown]
# TASK 1:
#
# You need to check the file Existence and Verify if the file check.txt exists and inform the user if it does not. Output an appropriate message indicating whether the file exists.
#
# If the file does exist:
#
# Output message:
# The file '/home/user/check.txt' exists.
#
# If the file does not exist:
#
# Output message:
#
# The file '/home/user/check.txt' does not exists.

# %%
#!/bin/bash

# file="check.txt"

# if [ -e "$file" ]; then
#         echo "The file $(pwd)/$file exists"
# else
#         echo "The file $(pwd)/$file does not exists"
# fi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# TASK 2:
#
# Check File Type. Verify whether check.txt is a regular file and not a directory using appropriate flags. Continue editing the file_info.sh script and output an appropriate message indicating whether the file is a regular file.
#
# If check.txt is a regular file:
#
# Output message:
#
# The file '/home/user/check.txt' is a regular file.
#
# If check.txt is not a regular file:
#
# Output message:
#
# The file '/home/user/check.txt' does not correspond to a regular file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# TASK 3:
#
# Check File Readability. Determine if check.txt is readable and notify the user accordingly. Output an appropriate message indicating whether the file is readable.
#
# If check.txt is readable:
#
# Output message:
#
# The file '/home/user/check.txt' is readable.
#
# If check.txt is not readable:
#
# Output message:
#
# The file '/home/user/check.txt' is not readable.
# Note: You need to check th full path /home/user/check.txt of this file check.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Q11. DevOps Class - 6-Assignment - 3

# %% [markdown]
# In the script file user_choice.sh already present on path /home/user write a script that uses the read command to ask the user to choose between start, stop, and status. Based on the user's input, the script should display a message about a fictional service (e.g., "Starting the service", "Stopping the service", "Service is running"). This assignment is designed to improve skills in creating interactive scripts and using conditional logic to handle user input.

# %% [markdown]
# ---

# %% [markdown]
# TASK-1:
#
# Prompt the User for Input. Develop the initial part of the shell script to ask the user to choose between 'start', 'stop', and 'status' and use the read command to capture the user's input.

# %%
# #!/bin/bash

# echo "Please choose an action (start, stop, status):"
# read action

# %% [markdown]
# ---

# %% [markdown]
# TASK-2:
#
# Implement Conditional Responses. Based on the input received, display a corresponding message about the service's state. Use a case statement to handle the user's input. Display a message for each possible input ('start', 'stop', 'status').
#
#
# Output Messages:
#
# 1. To start the service:
#
# Starting the service...
#
# 2. To stop the service:
#
# Stopping the service...
#
# 3. To check the status of service:
#
# The service is running.

# %%
# #!/bin/bash

# echo "Please choose an action (start, stop, status):"
# read action

# case $action in
#         start)
#                 echo "Starting the service..."
#                 # command to start the service
#                 ;;
#         stop)
#                 echo "Stopping the service..."
#                 ;;
#         status)
#                 echo "The service is running."
# esac

# %% [markdown]
# ---

# %% [markdown]
# TASK-3:
#
# Handle Invalid Input. Ensure the script can handle unexpected input by displaying an appropriate message. Add a default case in the <b> case </b> statement to handle any input that is not 'start', 'stop', or 'status' and display an error message for invalid input.
#
# Output Message:
#
# Invalid option selected. Please enter start, stop, or status.
#
#
# Note: Make sure to use this command after completing every task: ./user_choice.sh

# %%
# #!/bin/bash

# echo "Please choose an action (start, stop, status):"
# read action

# case $action in
#         start)
#                 echo "Starting the service..."
#                 # command to start the service
#                 ;;
#         stop)
#                 echo "Stopping the service..."
#                 ;;
#         status)
#                 echo "The service is running."
#                 ;;
#         *)
#                 echo "Invalid option selected. Please enter start, stop, or status."
# esac

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Q12. DevOps Class - 6-Assignment - 4

# %% [markdown]
# Write a script called cleanup_temp.sh that utilizes wildcards to locate and list all .tmp files in a directory test_temp_dir. The script should prompt the user for confirmation before deleting these files, and proceed with deletion only if the user approves. This assignment aims to develop a shell script to effectively manage file cleanup operations while enhancing user interaction and command execution skills.

# %% [markdown]
# TASK 1:
#
# Use wildcards to find all .tmp files in the directory test_temp_dir and list them.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# TASK 2:
#
# Continue editing the cleanup_temp.sh script and Prompt the user for confirmation. Before deleting the files, prompt the user to confirm their intention to delete. Use the echo command to ask the user for confirmation to delete the listed .tmp files. Use the read command to capture the user's response.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# TASK 3:
#
# Now, you need to proceed with deletion only if the user confirms the action. Use an if statement to check the user's response. If the user confirms, delete the .tmp files. If the user does not confirm, exit the script without deleting the files. But for required task you need to delete the .tmp files.
#
#
# Note: Make sure to use sudo in your script to delete the file due to permission issues.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Q13. DevOps Class - 6-Assignment - 5

# %% [markdown]
# Raw Problem
#
# In the script file number_loop.sh already present on path /home/user write a script that prints the numbers from 1 to 20. Each number should be displayed on a new line with a message indicating the number. The message format should be: "Number X", where X is the actual number being printed.
#
# TASK:
#
# Write a for loop that iterates through the numbers 1 to 20. For each iteration, print the current number in the following format: "Number X".
#
# Output:
#
# Number 1
# Number 2
# Number 3
# ....
# Number 20

# %%
# #1/bin/bash

# for number in {1..20}
# do
#         echo "Number $number"
# done

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
