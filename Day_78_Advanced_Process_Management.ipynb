# %% [markdown]
# <a href="https://colab.research.google.com/github/sovank/learn-linux/blob/main/Day_78_Advanced_Process_Management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question - 15

# %% [markdown]
# TASK - 1 :
#
# There are various processes running in Linux system.Which command would you use to view a comprehensive list of all currently running processes on a Linux system? Store the command used to view a comprehensive list of all currently running processes in answer.txt using the below code:
#
# echo command_name >> /home/user/answer.txt

# %%
# Answer
# top
# echo top >> /home/user/answer.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# TASK - 2 :
#
# As part of managing your development environment, you need to start processes with different priority levels to ensure critical tasks get more CPU time and less critical ones do not interfere as much with system performance. You are asked to start a background process with a specific priority to simulate a low-priority task. Use the nice command to start a process that runs sleep 300 with a nice value of 10.

# %%
# Answer
# nice -n 10 sleep 300
# echo nice -n 10 sleep 300 >> /home/user/answer.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Q16. DevOps Class - 4 Assignment - 2

# %% [markdown]
# We have created a process sleep 600 in your lab environment.
#
# TASK - 1 :
#
# Utilize the top command to locate the running sleep process. What is the PID of this process as displayed in top ?
# Store the answer in answer.txt file using the below code:
#
# echo "Store_PID" >> /home/user/answer.txt

# %%
# Answer
# top
# echo 91 >> /home/user/answer.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# TASK - 2 :
#
# What is the nice value of the sleep process, as determined by using the top command?
# Store the answer in answer.txt file using the below code:
# echo "Store_NICE-VALUE" >> /home/user/answer.txt

# %%
# Answer
# top
# echo 10 >> /home/user/answer.txt

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Question 17

# %% [markdown]
# Now we have made some changes to priority of sleep command. Identify change and answer following:
#
# TASK - 1: Which command you have been use to change the priority of a process in the lab
# environment?

# %%
# Answer
# renice
  # --> command -> renice -n 19 sleep(or PID of a process)
# echo renice >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# TASK - 2: What is the new priority (nice value) of the process following its modification?
#
# Store the answer in answer.txt file using the below code:
#
# echo "new_value" >> /home/user/answer.txt

# %%
# Answer
  # Check the new priority
  # top
  # new NI value = 19
# echo 19 >> /home/user/answer.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \

# %% [markdown]
# ---

# %% [markdown]
# # Question 18

# %% [markdown]
# You are an intern at a software development company, and you've been given the responsibility of managing your local development environment. You've noticed that an unnecessary process called long_running_script is running and consuming system resources. Your task is to terminate this process to free up these resources.

# %% [markdown]
# TASK - 1:
#
# Find the process called long_running_script. Note the PID of the process.
#
# Store the answer in answer.txt file using the below code:
#
# echo PID_NAME >> /home/user/answer.txt

# %%
# Answer
# top
# pid name: long_running_sc with pid 96
# echo 96 >> /home/user/answer.txt

# %% [markdown]
# ---

# %% [markdown]
# TASK - 2 :
#
# Someone from the team wants to terminate the long_running_script process.
#
# Store the answer in answer.txt file using below code.
#
# echo command_name >> /home/user/answer.txt
#
#
# NOTE: Just write the command to kill the process. No need to kill the process in an environment.

# %%
# Answer
# echo kill 96 >> /home/user/answer.txt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
